# %% [markdown]
# ### **Data Mining Using Python**

# %% [markdown]
# <font color="red">File access required:</font> In Colab this notebook requires first uploading files **Shop.csv** and **Movies.csv** using the *Files* feature in the left toolbar. If running the notebook on a local computer, simply ensure these files are in the same workspace as the notebook.

# %%
# Set-up
import csv

# %% [markdown]
# **Look at CSV files:** TID,item pairs

# %%
# Read shopping dataset from CSV file
# Create dictionary "Sitems" with key = item and value = set of transactions
# Also set variable Snumtrans = number of transactions
Sitems = {}
trans = []  # list of transactions used to set Snumtrans
with open('Shop.csv') as f:
    rows = csv.DictReader(f)
    for r in rows:
        if r['item'] not in Sitems:
            Sitems[r['item']] = {r['TID']}
        else:
            Sitems[r['item']].add(r['TID'])
        if r['TID'] not in trans:
            trans.append(r['TID'])
Snumtrans = len(trans)
print('Number of transactions:', Snumtrans)
print('Number of distinct items:', len(Sitems))
print('Item dictionary:')
Sitems
# Out:
# Number of transactions: 5
# Number of distinct items: 5
# Item dictionary:
# {'milk': {'1', '2', '4', '5'},
#  'eggs': {'1', '3', '4'},
#  'juice': {'1', '2', '5'},
#  'cookies': {'2', '5'},
#  'chips': {'3', '5'}}

# %%
# Read movies dataset from CSV file
# Create dictionary "Mitems" with key = item and value = set of transactions
# Also set variable Mnumtrans = number of transactions
Mitems = {}
trans = []  # list of transactions used to set Mnumtrans
with open('Movies.csv') as f:
    rows = csv.DictReader(f)
    for r in rows:
        if r['item'] not in Mitems:
            Mitems[r['item']] = {r['TID']}
        else:
            Mitems[r['item']].add(r['TID'])
        if r['TID'] not in trans:
            trans.append(r['TID'])
Mnumtrans = len(trans)
print('Number of transactions (users):', Mnumtrans)
print('Number of distinct items (movies):', len(Mitems))
print('Item dictionary:')
Mitems.items()
# Out:
# Number of transactions (users): 1382
# Number of distinct items (movies): 123
# Item dictionary:
# dict_items([('The Fault in Our Stars', {'124830', '239816', '168240', '167831', '244116', '121896', '12924', '163775', '46770', '61803', '15530', '102371', '47173', '240694', '101420', '158208', '87907', '54212', '69391', '71352', '140380', '206146', '174077', '186450', '87127', '69759', '218424', '171673', '150676', '96530', '233542', '214778', '58296', '200931', '174147', '41453', '204050', '232320', '105996', '127474', '218669', '18805', '71268', '92094', '78715', '54858', '34280', '126898', '25851', '171575', '111288', '145755', '158048', '234322', '6573', '102901', '6802', '14642', '176880', '120662', '173452', '243482', '39827', '184307', '232001', '166205', '241916', '43142', '98509', '144712', '229131', '3508', '128203', '72265', '62076', '151368', '31198', '7353', '184040', '100316', '165260', '50601', '210968', '68551', '56323', '89200', '215987', '176', '29139', '191042', '22793', '4231', '206129', '4208', '115516', '105787', '55096', '114602', '237123', '134268', '221712', '28304', '128828', '121408', '241263', '152735', '15590', '38153', '36040', '152646', '153533'}), ('Boyhood', {'79910', '124830', '194682', '168240', '202380', '244116', '6592', '220810', '244769', '115171', '163775', '56344', '72725', '74793', '140741', '4588', '51681', '170329', '229857', '12354', '208149', '106668', '176725', '47173', '78095', '146607', '15823', '17264', '240694', '101420', '167614', '158208', '87907', '241577', '3962', '99848', '13710', '8215', '156989', '46106', '49159', '116345', '4987', '94344', '133012', '116822', '220049', '102294', '139205', '143932', '94774', '211373', '228748', '207834', '73132', '177422', '72653', '206146', '117731', '75198', '9444', '150148', '216969', '169154', '230758', '182194', '128655', '131820', '115786', '153764', '14902', '196576', '55980', '241656', '52898', '228452', '200039', '180951', '26073', '139324', '150186', '96721', '205045', '141192', '124349', '150676', '39014', '50188', '6199', '40611', '98054', '68079', '208473', '151584', '197358', '246994', '74343', '216620', '127474', '95669', '13399', '159840', '90271', '218669', '18805', '71268', '92094', '34018', '34280', '90516', '122188', '87948', '90727', '15273', '14588', '198726', '9585', '243657', '222218', '111288', '75928', '145755', '6573', '99004', '207966', '68930', '7556', '199241', '14883', '138121', '162786', '148467', '243482', '39827', '184307', '232001', '77949', '182961', '238755', '20316', '160895', '43142', '144712', '233042', '27365', '87122', '129638', '72265', '98732', '62076', '17915', '209357', '99876', '152679', '7353', '123552', '3967', '176875', '106700', '89562', '184040', '64144', '100316', '50601', '179447', '147652', '99742', '145136', '213606', '68551', '204770', '76891', '63672', '201218', '105750', '176', '34950', '215987', '214091', '27210', '29139', '94957', '179625', '66551', '232165', '57305', '71124', '4231', '48950', '214028', '206129', '39070', '4208', '110968', '70585', '105787', '5415', '94555', '132287', '24214', '233266', '196565', '73352', '126382', '126624', '34520', '221712', '71301', '204070', '75555', '35936', '27332', '246553', '15466', '40926', '44027', '77903', '3266', '241263', '213657', '125182', '15590', '38153', '36040', '176934', '153533', '247354', '6569'}), ('Big Hero 6', {'124830', '30814', '94839', '128909', '86759', '180177', '199832', '142239', '78473', '172916', '101420', '192921', '78731', '105122', '106554', '116822', '87514', '102294', '1503', '58663', '228295', '76895', '208823', '67073', '73440', '171673', '237953', '50188', '6199', '218549', '115527', '226479', '14588', '182171', '207158', '67168', '129894', '145755', '42036', '124677', '154671', '243482', '36893', '147824', '112910', '89099', '36445', '128859', '231073', '98732', '169713', '149321', '49952', '7657', '147660', '66207', '74289', '175887', '94246', '168533', '194518', '180743', '105750', '33895', '206129', '115516', '70585', '45835', '5415', '158701', '73352', '41829', '34520', '130073', '175674', '7555 ...

# %% [markdown]
# ### Some new Python features

# %%
# Iterating through dictionaries
for i in Sitems:
    print(i)
    print(Sitems[i])
# Out:
# milk
# {'1', '4', '5', '2'}
# eggs
# {'3', '1', '4'}
# juice
# {'1', '5', '2'}
# cookies
# {'5', '2'}
# chips
# {'3', '5'}

# %%
# Intersecting sets
# How many transactions contain both eggs and milk?
set1 = Sitems['eggs']
print('Transactions containing eggs:', set1)
set2 = Sitems['milk']
print('Transactions containing milk:', set2)
set3 = set1 & set2
print('Transactions containing both:', set3)
# print('Number of transactions containing both:', len(set3))
# Out:
# Transactions containing eggs: {'3', '1', '4'}
# Transactions containing milk: {'1', '4', '5', '2'}
# Transactions containing both: {'1', '4'}

# %% [markdown]
# ## Shopping dataset - frequent item-sets

# %% [markdown]
# ### Frequent item-sets of two

# %% [markdown]
# #### Print all pairs of items and the number of transactions they occur together in (see what's wrong and fix it)

# %%
for i1 in Sitems:
    for i2 in Sitems:
        common = len(Sitems[i1] & Sitems[i2])
        print([i1, i2, common])
# Out:
# ['milk', 'milk', 4]
# ['milk', 'eggs', 2]
# ['milk', 'juice', 3]
# ['milk', 'cookies', 2]
# ['milk', 'chips', 1]
# ['eggs', 'milk', 2]
# ['eggs', 'eggs', 3]
# ['eggs', 'juice', 1]
# ['eggs', 'cookies', 0]
# ['eggs', 'chips', 1]
# ['juice', 'milk', 3]
# ['juice', 'eggs', 1]
# ['juice', 'juice', 3]
# ['juice', 'cookies', 2]
# ['juice', 'chips', 1]
# ['cookies', 'milk', 2]
# ['cookies', 'eggs', 0]
# ['cookies', 'juice', 2]
# ['cookies', 'cookies', 2]
# ['cookies', 'chips', 1]
# ['chips', 'milk', 1]
# ['chips', 'eggs', 1]
# ['chips', 'juice', 1]
# ['chips', 'cookies', 1]
# ['chips', 'chips', 2]

# %% [markdown]
# #### Now only print pairs that meet support threshold

# %%
support = .3
for i1 in Sitems:
    for i2 in Sitems:
      if i1 < i2:
        common = len(Sitems[i1] & Sitems[i2])
        if common/Snumtrans > support:
          print(i1, '|', i2)
# Out:
# eggs | milk
# juice | milk
# cookies | milk
# cookies | juice

# %% [markdown]
# ### Frequent item-sets of three

# %%
support = .1
for i1 in Sitems:
    for i2 in Sitems:
        for i3 in Sitems:
            if i1 < i2 and i2 < i3:
                common = len(Sitems[i1] & Sitems[i2] & Sitems[i3])
                if common/Snumtrans > support:
                    print(i1, '|', i2, '|', i3)
# Out:
# eggs | juice | milk
# cookies | juice | milk
# chips | juice | milk
# chips | cookies | milk
# chips | cookies | juice

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset frequent item-sets**</font>

# %%
print(Mnumtrans, 'transactions (users)')
print(len(Mitems), 'distinct items (movies)')
# Out:
# 1382 transactions (users)
# 123 distinct items (movies)

# %% [markdown]
# #### Mine for frequent item-sets of three and four items in the Movies dataset. Find a single support threshold where the number of frequent item-sets of three items is more than 10 but less than 20, and the number of frequent item-sets of four items is more than 0.

# %%
# Frequent item-sets of three
support = 0.035  # You may need to adjust this value
count_3 = 0
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 and i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common/Mnumtrans > support:
                    print(i1, '|', i2, '|', i3)
                    count_3 += 1
print(f"Support: {support}")
print(f"3-itemsets count: {count_3}")
# Out:
# Boyhood | Inside Out | The Imitation Game
# Boyhood | Gone Girl | The Imitation Game
# Boyhood | Gone Girl | Inside Out
# Big Hero 6 | Boyhood | The Imitation Game
# Big Hero 6 | Boyhood | Gone Girl
# Big Hero 6 | Inside Out | The Imitation Game
# Big Hero 6 | Gone Girl | The Imitation Game
# Big Hero 6 | Gone Girl | Inside Out
# Gone Girl | Inside Out | The Imitation Game
# Fury | Gone Girl | The Imitation Game
# Support: 0.035
# 3-itemsets count: 10

# %%
# Frequent item-sets of four
support = 0.015  # SAME VALUE AS PREVIOUS CELL
count_4 = 0
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            for i4 in Mitems:
                if i1 < i2 and i2 < i3 and i3 < i4:
                    common = len(Mitems[i1] & Mitems[i2] & Mitems[i3] & Mitems[i4])
                    if common/Mnumtrans > support:
                        count_4 += 1

print(f"Support: {support}")
print(f"4-itemsets count: {count_4}")
# Out:
# Support: 0.015
# 4-itemsets count: 16

# %% [markdown]
# ## Shopping dataset - association rules

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence (see what's wrong and fix it)

# %%
# S -> i

confidence = .5
for lhs in frequentLHS:
    for i in Sitems:
        common = len(Sitems[lhs[0]] & Sitems[i])
        if common/lhs[1] > confidence:
            print(lhs[0], '->', i)
# Out:
# milk -> milk
# milk -> juice
# eggs -> milk
# eggs -> eggs
# juice -> milk
# juice -> juice
# juice -> cookies

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
# S = [JUICE, MILK]
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient confidence

# %%
confidence = .5
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            if common/lhs[2] > confidence:
                print(lhs[0], '|', lhs[1], '->', i)
# Out:
# juice | milk -> cookies

# %% [markdown]
# ## Shopping dataset - association rules with lift instead of confidence

# %% [markdown]
# ### Association rules with one item on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of one item, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i in Sitems:
    if len(Sitems[i])/Snumtrans > support:
        frequentLHS.append([i,len(Sitems[i])])
print(frequentLHS)
# Out:
# [['milk', 4], ['eggs', 3], ['juice', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[i])
            lift = (common/lhs[1]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '->', i, ' lift:', lift)
# Out:
# milk -> juice  lift: 1.25
# milk -> cookies  lift: 1.25
# juice -> milk  lift: 1.25
# juice -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### Association rules with two items on the left-hand side

# %% [markdown]
# #### First compute frequent item-sets of two items, as candidate left-hand sides of assocation rules. Include the number of transactions the items occur in.

# %%
support = .5
frequentLHS = []
for i1 in Sitems:
    for i2 in Sitems:
        if i1 < i2:
            common = len(Sitems[i1] & Sitems[i2])
            if common/Snumtrans > support:
                frequentLHS.append([i1,i2,common])
print(frequentLHS)
# Out:
# [['juice', 'milk', 3]]

# %% [markdown]
# #### Now find right-hand side items with sufficient lift

# %%
liftthresh = 1
for lhs in frequentLHS:
    for i in Sitems:
        if i not in lhs:
            common = len(Sitems[lhs[0]] & Sitems[lhs[1]] & Sitems[i])
            lift = (common/lhs[2]) / (len(Sitems[i])/Snumtrans)
            if lift > liftthresh:
                print(lhs[0], '|', lhs[1], '->', i, ' lift:', lift)
# Out:
# juice | milk -> cookies  lift: 1.6666666666666665

# %% [markdown]
# ### <font color = 'green'>**Your Turn - Movies dataset association rules**</font>

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and confidence thresholds (need not be the same) so the number of association rules is more than 10 but less than 20.

# %%
# Association rules with three items on the left-hand side
# Hint: Make sure to include the code from the seprate cells above that
#   together implement the two steps of association rule mining
support = 0.04
confidence = 0.39
frequentLHS = []
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 and i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common/Mnumtrans > support:
                    frequentLHS.append([i1, i2, i3, common])

print(f"Number of frequent 3-itemsets: {len(frequentLHS)}")

rule_count = 0
for lhs in frequentLHS:
    for i in Mitems:
        if i not in lhs:
            common = len(Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[i])
            conf = common/lhs[3]
            if conf > confidence:
                print(lhs[0], '|', lhs[1], '|', lhs[2], '->', i, f' confidence: {conf:.3f}')
                rule_count += 1

print(f"\nTotal association rules: {rule_count}")
# Out:
# Number of frequent 3-itemsets: 8
# Boyhood | Gone Girl | The Imitation Game -> Big Hero 6  confidence: 0.484
# Boyhood | Gone Girl | The Imitation Game -> Inside Out  confidence: 0.442
# Boyhood | Gone Girl | The Imitation Game -> Fury  confidence: 0.411
# Big Hero 6 | Boyhood | The Imitation Game -> Inside Out  confidence: 0.614
# Big Hero 6 | Boyhood | The Imitation Game -> Gone Girl  confidence: 0.807
# Big Hero 6 | Boyhood | The Imitation Game -> Fury  confidence: 0.491
# Big Hero 6 | Boyhood | Gone Girl -> The Imitation Game  confidence: 0.821
# Big Hero 6 | Boyhood | Gone Girl -> Inside Out  confidence: 0.607
# Big Hero 6 | Boyhood | Gone Girl -> Fury  confidence: 0.482
# Big Hero 6 | Inside Out | The Imitation Game -> Gone Girl  confidence: 0.578
# Big Hero 6 | Gone Girl | The Imitation Game -> Inside Out  confidence: 0.496
# Big Hero 6 | Gone Girl | Inside Out -> Boyhood  confidence: 0.400
# Big Hero 6 | Gone Girl | Inside Out -> The Imitation Game  confidence: 0.694
# Gone Girl | Inside Out | The Imitation Game -> Boyhood  confidence: 0.408
# Gone Girl | Inside Out | The Imitation Game -> Big Hero 6  confidence: 0.573
# Fury | Gone Girl | The Imitation Game -> Boyhood  confidence: 0.557
# Fury | Gone Girl | The Imitation Game -> Big Hero 6  confidence: 0.514
# Fury | Gone Girl | The Imitation Game -> Inside Out  confidence: 0.514
#
# Total association rules: 18

# %% [markdown]
# #### Mine for association rules in the Movies dataset with three items on the left-hand side. Find support and lift thresholds so the number of association rules is more than 10 but less than 20. Only consider lift thresholds > 1.

# %%
# Association rules with three items on the left-hand side
support = 0.08
liftthresh = 9

frequentLHS = []
for i1 in Mitems:
    for i2 in Mitems:
        for i3 in Mitems:
            if i1 < i2 and i2 < i3:
                common = len(Mitems[i1] & Mitems[i2] & Mitems[i3])
                if common/Mnumtrans > support:
                    frequentLHS.append([i1, i2, i3, common])

print(f"Number of frequent 3-itemsets: {len(frequentLHS)}")

rule_count = 0
for lhs in frequentLHS:
    for i in Mitems:
        if i not in lhs:
            common = len(Mitems[lhs[0]] & Mitems[lhs[1]] & Mitems[lhs[2]] & Mitems[i])
            lift = (common/lhs[3]) / (len(Mitems[i])/Mnumtrans)
            if lift > liftthresh:
                print(lhs[0], '|', lhs[1], '|', lhs[2], '->', i, f' lift: {lift:.3f}')
                rule_count += 1

print(f"\nTotal association rules: {rule_count}")
# Out:
# Number of frequent 3-itemsets: 1
# Big Hero 6 | Gone Girl | The Imitation Game -> Flowers in the Attic  lift: 11.613
# Big Hero 6 | Gone Girl | The Imitation Game -> Whitey: United States of America v. James J. Bulger  lift: 11.613
# Big Hero 6 | Gone Girl | The Imitation Game -> The Wonders  lift: 11.613
# Big Hero 6 | Gone Girl | The Imitation Game -> Action Jackson  lift: 11.613
# Big Hero 6 | Gone Girl | The Imitation Game -> Breathe  lift: 11.613
# Big Hero 6 | Gone Girl | The Imitation Game -> Court  lift: 11.613
# Big Hero 6 | Gone Girl | The Imitation Game -> The Humbling  lift: 11.613
# Big Hero 6 | Gone Girl | The Imitation Game -> I'll See You in My Dreams  lift: 11.613
# Big Hero 6 | Gone Girl | The Imitation Game -> Outcast  lift: 11.613
# Big Hero 6 | Gone Girl | The Imitation Game -> Time Out of Mind  lift: 11.613
# Big Hero 6 | Gone Girl | The Imitation Game -> Far from Men  lift: 11.613
#
# Total association rules: 11
